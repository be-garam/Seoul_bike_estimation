# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import forestplot as fp

# %%
#green 전체, 도시, 시골 table
green_table = pd.DataFrame([["clear_day", -0.0076, -0.014, -0.014],
                           ['day_view_time', 0.0014, -0.005, 0.008],
                            ['lst', 0.1033, 0.096, 0.111],
                            ['bike_place', 0.6202, 0.396, 0.844],
                            ['bike', -0.5388, -0.761, -0.316],
                            ['population', 0.0206, 0.012, 0.029]], columns = ['label', 'coef', '[0.025', '0.975]'])
green_table
# Out:
#            label    coef  [0.025  0.975]
# 0      clear_day -0.0076  -0.014  -0.014
# 1  day_view_time  0.0014  -0.005   0.008
# 2            lst  0.1033   0.096   0.111
# 3     bike_place  0.6202   0.396   0.844
# 4           bike -0.5388  -0.761  -0.316
# 5     population  0.0206   0.012   0.029

# %%
fp.forestplot(green_table,  # the dataframe with results data
              estimate="coef",  # col containing estimated effect size 
              ll="[0.025", hl="0.975]",  # columns containing conf. int. lower and higher limits
              varlabel="label",  # column containing variable label
              ylabel="SeongDonggu",  # y-label title
              xlabel="Regression coefficient"  # x-label title
              )
# Out:
# <AxesSubplot:xlabel='Regression coefficient', ylabel='SeongDonggu'>
